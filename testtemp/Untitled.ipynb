# %%
import requests
from bs4 import BeautifulSoup
import re
from collections import Counter

# %%
Host="https://www.1111.com.tw"
page=[]
for i in range(1,20):
    pages=Host+'/job-bank/job-index.asp?si=1&ss=s&d0=140200,140100,140300,140400&page='+str(i)
    page.append(pages)
page
# Out:
# ['https://www.1111.com.tw/job-bank/job-index.asp?si=1&ss=s&d0=140200,140100,140300,140400&page=1',
#  'https://www.1111.com.tw/job-bank/job-index.asp?si=1&ss=s&d0=140200,140100,140300,140400&page=2',
#  'https://www.1111.com.tw/job-bank/job-index.asp?si=1&ss=s&d0=140200,140100,140300,140400&page=3',
#  'https://www.1111.com.tw/job-bank/job-index.asp?si=1&ss=s&d0=140200,140100,140300,140400&page=4',
#  'https://www.1111.com.tw/job-bank/job-index.asp?si=1&ss=s&d0=140200,140100,140300,140400&page=5',
#  'https://www.1111.com.tw/job-bank/job-index.asp?si=1&ss=s&d0=140200,140100,140300,140400&page=6',
#  'https://www.1111.com.tw/job-bank/job-index.asp?si=1&ss=s&d0=140200,140100,140300,140400&page=7',
#  'https://www.1111.com.tw/job-bank/job-index.asp?si=1&ss=s&d0=140200,140100,140300,140400&page=8',
#  'https://www.1111.com.tw/job-bank/job-index.asp?si=1&ss=s&d0=140200,140100,140300,140400&page=9',
#  'https://www.1111.com.tw/job-bank/job-index.asp?si=1&ss=s&d0=140200,140100,140300,140400&page=10',
#  'https://www.1111.com.tw/job-bank/job-index.asp?si=1&ss=s&d0=140200,140100,140300,140400&page=11',
#  'https://www.1111.com.tw/job-bank/job-index.asp?si=1&ss=s&d0=140200,140100,140300,140400&page=12',
#  'https://www.1111.com.tw/job-bank/job-index.asp?si=1&ss=s&d0=140200,140100,140300,140400&page=13',
#  'https://www.1111.com.tw/job-bank/job-index.asp?si=1&ss=s&d0=140200,140100,140300,140400&page=14',
#  'https://www.1111.com.tw/job-bank/job-index.asp?si=1&ss=s&d0=140200,140100,140300,140400&page=15',
#  'https://www.1111.com.tw/job-bank/job-index.asp?si=1&ss=s&d0=140200,140100,140300,140400&page=16',
#  'https://www.1111.com.tw/job-bank/job-index.asp?si=1&ss=s&d0=140200,140100,140300,140400&page=17',
#  'https://www.1111.com.tw/job-bank/job-index.asp?si=1&ss=s&d0=140200,140100,140300,140400&page=18',
#  'https://www.1111.com.tw/job-bank/job-index.asp?si=1&ss=s&d0=140200,140100,140300,140400&page=19']

# %%
for i in page:
    res=requests.get(i)
    soup=BeautifulSoup(res.text,'lxml')
    buttons=soup.select('div.jbInfoin > h3 > a')
    link = []
    for i in buttons:
        link.append(i['href'])
link
# Out:
# ['//www.1111.com.tw/job/79812705/',
#  '//www.1111.com.tw/job/79810714/',
#  '//www.1111.com.tw/job/79810713/',
#  '//www.1111.com.tw/job/79810710/',
#  '//www.1111.com.tw/job/79810709/',
#  '//www.1111.com.tw/job/79801464/',
#  '//www.1111.com.tw/job/79794662/',
#  '//www.1111.com.tw/job/79788476/',
#  '//www.1111.com.tw/job/79778157/',
#  '//www.1111.com.tw/job/79778147/',
#  '//www.1111.com.tw/job/79772302/',
#  '//www.1111.com.tw/job/79754082/',
#  '//www.1111.com.tw/job/79754078/',
#  '//www.1111.com.tw/job/79751943/',
#  '//www.1111.com.tw/job/79745199/',
#  '//www.1111.com.tw/job/79733869/',
#  '//www.1111.com.tw/job/79733864/',
#  '//www.1111.com.tw/job/79733856/',
#  '//www.1111.com.tw/job/79733800/',
#  '//www.1111.com.tw/job/79733725/']

# %%
sk=requests.get('https://www.1111.com.tw/job/79812705/')
BS=BeautifulSoup(sk.text,'lxml')
button=BS.select('dl.dataList')[1].text
p=re.compile('[A-Z]+[+#]*')
words=p.findall(button.upper())

# %%
button
# Out:
# '\n身份類別：\n不拘\n學歷限制：\n專科 以上畢業\n科系限制：\n不拘\n工作經驗：\n3年以上工作經驗\n電腦專長：\nJava Script、HTML\n'

# %%
BS
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
# <html>
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <title>Javascript 網頁工程師-卡貓科技有限公司-台中市西屯區-工作-1111求職找好工作的人力銀行</title>
# <meta content="Javascript 網頁工程師-卡貓科技有限公司-台中市西屯區-工作-1111求職找好工作的人力銀行" name="title"/>
# <meta content="網站程式設計師,電玩程式設計師,軟體工程師,Javascript 網頁工程師工作,找工作,求職,人力銀行" name="keywords"/>
# <meta content="Javascript 網頁工程師工作,位於台中市西屯區,日班,熟悉 Javacsript者。 有用Javascript寫過遊戲者優先錄取 熟Java者亦可,意者請上1111投遞履歷表安排面試。" name="description"/>
# <meta content="no-cache" http-equiv="Cache-Control"/>
# <meta content="no-cache" http-equiv="Pragma"/>
# <meta content="index,follow" name="robots"/>
# <meta content="Javascript 網頁工程師-卡貓科技有限公司-台中市西屯區-工作-1111求職找好工作的人力銀行" property="og:title"/>
# <meta content="Javascript 網頁工程師工作,位於台中市西屯區,日班,熟悉 Javacsript者。 有用Javascript寫過遊戲者優先錄取 熟Java者亦可,意者請上1111投遞履歷表安排面試。" property="og:description"/>
# <meta content="https://www.1111.com.tw/talents/MicroBlogging/images/facebook_banner01.jpg" property="og:image"/>
# <meta content="https://www.1111.com.tw//job-bank/job-description.asp?eNo=79812705" property="og:url"/>
# <meta content="網站程式設計師,電玩程式設計師,軟體工程師,Javascript 網頁工程師工作,找工作,求職,人力銀行" property="og:keywords"/>
# <link href="https://www.1111.com.tw/job-bank/job-description.asp?eNo=79812705" rel="canonical"/>
# <link href="https://www.1111.com.tw/mobileweb/job-description.asp?eNo=79812705" media="only screen and (max-width: 640px)" rel="alternate"/>
# <link href="https://www.1111.com.tw/mobileweb/job-description.asp?eNo=79812705" media="handheld" rel="alternate"/>
# <link href="https://www.1111.com.tw/talents/MicroBlogging/images/facebook_banner01.jpg" rel="image_src"/>
# <link href="/css102/footer.css" rel="stylesheet" type="text/css"/>
# <link href="/zone/service/css/floatAD.css" rel="stylesheet" type="text/css"/>
# <link href="/job-bank/css/Comp-Job-20131108/reset.css" rel="stylesheet" type="text/css"/>
# <link href="/job-bank/css/Comp-Job-20131108/searchBasic.css?v=201702131515" rel="stylesheet" type="text/css"/>
# <link href="/job-bank/css/Comp-Job-20131108/common.css?v=201702131515" rel="stylesheet" type="text/css"/>
# <link href="/job-bank/css/Comp-Job-20131108/item.css?v=201702131515" rel="stylesheet" type="text/css"/>
# <link href="/job-bank/css/Comp-Job-20131108/jobdescripRight.css?v=201702131515" rel="stylesheet" type="text/css"/>
# <link href="/job-bank/css/Comp-Job-20131108/folder.css?v=201702131515" rel="stylesheet" type="text/css"/>
# <link href="/job-bank/css/job-description-20130522/job-salary.css?v=201702131515" rel="stylesheet" type="text/css"/>
# <link href="/includesU/fancyBox.2.1.5/source/jquery.fancybox.css?v=201702131515" rel="stylesheet"/>
# <link href="/includesU/jqWindowsEngine/jquery.windows-engine.css?v=201702131515" rel="stylesheet" type="text/css"/>
# <link href="/css/jquery.alerts.css?v=201702131515" rel="stylesheet"/>
# <link href="/job-bank/css/Comp-Job-20131108/vac-f.css?v=201702131515" rel="stylesheet" type="text/css"/>
# <script src="/includesU/jquery-1.7.min.js" type="text/javascript"></script>
# <link href="/includesU/font_awesome/css/font-awesome.min.css" rel="stylesheet" type="text/css"/>
# <link href="/includesU/lightbox/lightbox.css?v=201702131515" rel="stylesheet" type="text/css"/>
# <script src="/includesU/lightbox/lightbox.js?v=201702131515" type="text/javascript"></script>
# </head>
# <body>
# <div class="path" itemscope="" itemtype="//data-vocabulary.org/Breadcrumb" style="margin-top: 40px;">目前位置：<a href="//www.1111.com.tw/" itemprop="url"><span itemprop="title">1111人力銀行</span></a><span itemprop="child" itemscope="" itemtype="//data-vocabulary.org/Breadcrumb">  &gt; <a href="//www.1111.com.tw/job-bank/job-index.asp?ss=s&amp;tt=1,2,4,16&amp;d0=140213&amp;si=1&amp;ps=40&amp;trans=1" itemprop="url" target="_blank"><span itemprop="title">找工作</span></a> &gt; <span itemprop="child" itemscope="" itemtype="//data-vocabulary.org/Breadcrumb"><a href="/job-bank/company-description.asp?nNo=71696908" itemprop="url" onfocus="this.blur()" onmouseout="this.style.textDecoration = 'none';" onmouseover="this.style.textDecoration = 'underline';"><span itemprop="title">卡貓科技有限公司</span></a> &gt; <span itemprop="child" itemscope="" itemtype="//data-vocabulary.org/Breadcrumb"><a href="/job-bank/company-description.asp?nNo=71696908&amp;sec=emplist" itemprop="url"><span itemprop="title">職缺列表</span></a> &gt; <a href="/job-bank/job-description.asp?eNo=79812705" itemprop="url"><span itemprop="title">Javascript 網頁工程師</span></a></span></span></span></div>
# <div id="wrap"><input class="go" id="backTop" type="button" value="TOP"/> <div id="commonTop">
# <h1>Javascript 網頁工程師</h1> <div class="topMail2Organ"><input class="button navy" onclick="Mail2OrganNew(this,79812705, 'NM', '');" type="button" value="我要應徵"/></div> <div class="topCollect"><input class="button navy2" id="divCollect1" type="button" value="收藏工作"/></div> <div class="navbar">
# <ul>
# <li><a href="/job-bank/company-description.asp?nNo=71696908">卡貓科技有限公司</a></li>
# <li><a href="/job-bank/company-description.asp?nNo=71696908&amp;sec=emplist">本公司其他工作<span id="otherJobsC"></span></a></li>
# </ul>
# <div class="share"><span>分享：</span> <a class="fb" href="javascript:fb_click();" title="facebook分享"></a> <a class="twitter" href="javascript:twitter_click();" title="twitter分享"></a> <a class="glp" href="javascript:google_click();" title="google分享"></a> <a class="plurk" href="javascript:plurk_click();" title="plurk分享"></a> <a class="weibo" href="javascript:sina_click();" title="新浪微博分享"></a> <a class="email" href="javascript:void(0);" id="tofriend1" title="轉寄好友分享"></a></div>
# <!--share end--> </div>
# <!--  navbar end -->
# </div> <div class="doc">
# <div class="w230 fr" id="rightblock">
# <div id="matchScore">
# </div>
# <div id="distanceShow"></div>
# <script language="javascript" src="//maps.google.com/maps/api/js?sensor=true" type="text/javascript"> </script><script language="javascript" src="/job-bank/job-description-distance.js?v="></script><div id="aboutShow"></div>
# <script src="/includesU/ShareObj/swfobject.js" type="text/javascript"></script><script language="javascript" type="text/javascript">$(document).ready(function () {    var flashvars = {soname: "eViewsLog"};    var params = {        menu: "false",        quality: 'high',        wmode: 'transparent',        scale: 'noscale',        salign: 'lt'    };    var attributes = {};    swfobject.embedSWF("/includesU/ShareObj/ShareObject.swf", "eViewsLog", "1", "1", "9.0.0", "//www.macromedia.com/go/getflashplayer", flashvars, params, attributes);    setTimeout("saveEViewData()",1000);	 if ($('#rightblock').height()>=450){$('#block3').addClass('w680');}});function saveEViewData(){    var objeViewsLog = $("#eViewsLog")[0].getSODataAll();    var objemployeeNo = objeViewsLog['employeeNo'];   if(objemployeeNo != null){    objemployeeNo = objemployeeNo.replace("79812705,","");}    objemployeeNo = '79812705,' + objemployeeNo;    $("#eViewsLog")[0].saveSOData('employeeNo',objemployeeNo,0);   $.post('/job-bank/job-description-viewlist.asp', { 'viewlist': objemployeeNo }, function (data) { $('#jobRec').html(data); });}function clearEViewData(){   var objDel = $("#eViewsLog")[0].removeSOData();   saveEViewData();}</script><div id="eViewsLog" style="display:none;"></div><div class="jobRec" id="jobRec"></div> </div><div id="dutysalary0" style="position:absolute; z-index:99 ;background-color:white; display:none ;">
# <div class="show">
# <div class="style4" style="float:left; "> ◎ 更多「<a href="/job-bank/category.asp?cat=1&amp;d=140213&amp;city=1" style="color:#FFF;" target="_blank">網站程式設計師</a>」薪資職能說明</div><div style="float:right; padding-right:5px; padding-top:3px; cursor:pointer"><img onclick="document.getElementById('dutysalary0').style.display = 'none';" src="/images/btn_closewin.gif"/></div></div>
# <div align="left" class="box show-1">
# <li class="three"><a ad_id="204616" href="http://www.jobsalary.com.tw/index.asp?duty=140213" onclick="setHref('204616');"> 網站程式設計師-職務解說 </a></li>
# <li class="three"><a href="http://www.jobsalary.com.tw/salary2.asp?duty=140213" onclick="setHref('204616');"> 網站程式設計師-薪資比較 </a></li>
# <li class="three"><a href="http://www.jobsalary.com.tw/salary5.asp?duty=140213" onclick="setHref('204616');"> 網站程式設計師-能力需求 </a></li>
# <li class="three"><a href="http://www.jobsalary.com.tw/salary6.asp?duty=140213" onclick="setHref('204616');"> 網站程式設計師-競爭比較 </a></li>
# <li class="three"><a ad_id="204616" href="http://knowledge.1111.com.tw/vote.aspx?dutyB=140213" onclick="setHref('204616');" target="_blank"> 網站程式設計師-職務大蒐秘 </a></li>
# <li class="three"><a href="/job-bank/job-index.asp?ss=s&amp;tt=1,2,4,16&amp;d0=140213&amp;si=1&amp;ps=40&amp;trans=1" onclick="setHref('204616');" target="_blank"> 更多網站程式設計師相關工作 </a></li>
# </div>
# </div><div id="dutysalary1" style="position:absolute; z-index:99 ;background-color:white; display:none; left:104px">
# <div class="show"><div class="style4" style="float:left; "> ◎ 更多「<a href="/job-bank/category.asp?cat=1&amp;d=140212&amp;city=1" style="color:#FFF;" target="_blank">電玩程式設計師</a>」薪資職能說明</div><div style="float:right; padding-right:5px; padding-top:3px; cursor:pointer"><img onclick="document.getElementById('dutysalary1').style.display = 'none';" src="/images/btn_closewin.gif"/></div></div>
# <div align="left" class="box show-1">
# <li class="three"><a href="http://www.jobsalary.com.tw/index.asp?duty=140212" onclick="setHref('204616');"> 電玩程式設計師-職務解說 </a></li>
# <li class="three"><a href="http://www.jobsalary.com.tw/salary2.asp?duty=140212" onclick="setHref('204616');"> 電玩程式設計師-薪資比較 </a></li>
# <li class="three"><a href="http://www.jobsalary.com.tw/salary5.asp?duty=140212" onclick="setHref('204616');"> 電玩程式設計師-能力需求 </a></li>
# <li class="three"><a href="http://www.jobsalary.com.tw/salary6.asp?duty=140212" onclick="setHref('204616');"> 電玩程式設計師-競爭比較 </a></li>
# <li class="three"><a href="http://knowledge.1111.com.tw/vote.aspx?dutyB=140212" onclick="setHref('204616');" target="_blank"> 電玩程式設計師-職務大蒐秘 </a></li>
# <li class="three"><a href="/job-bank/job-index.asp?ss=s&amp;tt=1,2,4,16&amp;d0=140212&amp;si=1&amp;ps=40&amp;trans=1" onclick="setHref('204616');" target="_blank"> 更多電玩程式設計師相關工作 </a></li>
# </div>
# </div><div id="dutysalary2" style="position:absolute; z-index:99 ;background-color:white; display:none; left:208px">
# <div class="show"><div class="style4" style="float:left; "> ◎ 更多「<a href="/job-bank/category.asp?cat=1&amp;d=140202&amp;city=1" style="color:#FFF;" target="_blank">軟體工程師</a>」薪資職能說明</div><div style="float:right; padding-right:5px; padding-top:3px; cursor:pointer"><img onclick="document.getElementById('dutysalary2').style.display = 'none';" src="/images/btn_closewin.gif"/></div></div>
# <div align="left" class="box show-1">
# <li class="three"><a href="http://www.jobsalary.com.tw/index.asp?duty=140202" onclick="setHref('204616');"> 軟體工程師-職務解說 </a></li>
# <li class="three"><a href="http://www.jobsalary.com.tw/salary2.asp?duty=140202" onclick="setHref('204616');"> 軟體工程師-薪資比較 </a></li>
# <li class="three"><a href="http://www.jobsalary.com.tw/salary5.asp?duty=140202" onclick="setHref('204616');"> 軟體工程師-能力需求 </a></li>
# <li class="three"><a href="http://www.jobsalary.com.tw/salary6.asp?duty=140202" onclick="setHref('204616');"> 軟體工程師-競爭比較 </a></li>
# <li class="three"><a href="http://knowledge.1111.com.tw/vote.aspx?dutyB=140202" onclick="setHref('204616');" target="_blank"> 軟體工程師-職務大蒐秘 </a></li>
# <li class="three"><a href="/job-bank/job-index.asp?ss=s&amp;tt=1,2,4,16&amp;d0=140202&amp;si=1&amp;ps=40&amp;trans=1" onclick="setHref('204616');" target="_blank"> 更多軟體工程師相關工作 </a></li>
# </div>
# </div><span id="salaryReportContent" style="display:none"> <span><a ad_id="204614" href="http://www.jobsalary.com.tw/salarysummary.aspx?codeNo=140213" onclick="setHref('204614');" target="_blank"><img align="absmiddle" height="24" src="/job-bank/images/Comp-Job-20131108/sicon08a.png" width="23"/>薪資分析</a></span></span> <div class="w680" id="midblock">
# <div class="section w570">
# <h3>工作內容</h3>
# <dl class="dataList">
# <dt>工作說明：</dt>
# <dd><p>熟悉 Javacsript者。 <br/>有用Javascript寫過遊戲者優先錄取 <br/>熟Java者亦可</p></dd>
# <dt>工作地點：</dt>
# <dd>台中市西屯區 朝富路213號15樓之1  <a ad_id="204611" class="fancybox fancybox.iframe" href="/includesU/locateMap.asp?ono=71696908&amp;eno=79812705&amp;xpoint=0&amp;ypoint=0&amp;addr=" id="showmap" onclick="setHref('204611');"><img align="absmiddle" border="0" rel="#mies1" src="//www.1111.com.tw/talents/images/icon_map.gif" title="電子地圖"/></a> </dd>
# <dt>工作時間：</dt>
# <dd>日班</dd>
# <dt>休假制度：</dt>
# <dd>週休二日</dd>
# <dt>工作性質：</dt>
# <dd>全職</dd>
# <dt>職務類別：</dt>
# <dd><span id="esDuty0">網站程式設計師</span>、<span id="esDuty1">電玩程式設計師</span>、<span id="esDuty2">軟體工程師</span></dd>
# <dt>工作待遇：</dt>
# <dd>月薪 45,000元 至 60,000元　<span id="salaryReport"></span></dd>
# <dt>需求人數：</dt>
# <dd>1~2人</dd>
# <dt>管理人數：</dt>
# <dd>10人以內</dd>
# <dt>到職日期：</dt>
# <dd>不限</dd>
# <dt>職缺更新：</dt>
# <dd>2017/5/6</dd>
# </dl>
# </div>
# <div class="section">
# <h3>求才條件</h3>
# <dl class="dataList">
# <dt>身份類別：</dt>
# <dd>不拘</dd>
# <dt>學歷限制：</dt>
# <dd>專科 以上畢業</dd>
# <dt>科系限制：</dt>
# <dd><a ad_id="223573" href="https://university.1111.com.tw/univ_department.aspx" onclick="setHref('223573');" target="_blank">不拘</a></dd>
# <dt>工作經驗：</dt>
# <dd>3年以上工作經驗</dd>
# <dt>電腦專長：</dt>
# <dd>Java Script、HTML</dd>
# </dl>
# </div>
# </div>
# <div class="folder section" id="block3">
# <h3>應徵方式</h3>
# <div class="des">
# <dl class="dataList" style="padding-right: 10px;">
# <dt>聯絡人員：</dt>
# <dd>張先生</dd>
# </dl>
# <div class="CONTENT">
# <div class="react">
# <input class="button navy" onclick="Mail2OrganNew(this,79812705, 'NM', '');" type="button" value="我要應徵"/> <span id="recruits"></span>
# <br/>
# <br/>
# <a class="icon_edit" href="//www.1111.com.tw/talents/membercenter/resumeNew_1.asp?agent=home_20170507" target="_blank">填寫履歷</a>
# <a class="icon_fb" href="javascript:fb_click();">FB分享</a>
# <a class="icon_mail" href="javascript:void(0);" id="tofriend">轉寄好友</a>
# <a class="icon_print" href="#" onclick="$('.toplinkzone').hide();window.print();$('.toplinkzone').show();">友善列印</a>
# <a class="icon_report" href="/help/service.asp?eNo=79812705" target="_blank">我要舉發</a>
# <a class="icon_salary" href="//salary.1111.com.tw/" target="_blank">薪資落點</a>
# </div>
# <div style="position:absolute;">
# <div id="showcollectlayer" style="width:250px; font-size:13px; line-height:20px; border:1px solid #666666; background-color:#E8F2FF; padding:5px; color:#003366F; position:relative;display:none;"><div style="color:red;text-align:center">提醒您</div>『我的收藏』功能可以幫助您暫時儲存工作，為1111會員獨享的會員服務之一，若您需使用更多求職服務，請您立即加入/登入會員！
# <div style="text-align:center; padding:5px;"><input id="button" name="button" onclick="location.href='/talents/memberLogin.asp?ref='+location.href+'?item=EmployeeAddCollect';" style="background-color:#0066CC; color:white; border:1px solid #0099CC; padding:2px;" type="button" value="立即加入/登入"/></div>
# </div>
# </div>
# <ul class="warnings">
# <b>1111人力銀行提醒您：</b>
# <li>主動應徵，會增加更多面試機會，履歷表關閉狀態，仍可投遞履歷表！</li>
# <li>切記前往面試，請留意求職安全
#                             <ol>
# <li>「不繳錢、不購買、不辦卡、不隨意簽約、證件不離身 」的五不原則。 </li>
# <li>保護自己的三要原則「 要陪同、要確定、要存疑 」。 </li>
# <li>不要到非公司或地區偏遠的地點面試。</li>
# <li>不要因為急於找到工作，而將提款卡、帳戶、存摺及密碼等資料交給他人。 </li>
# <li>如遇任何求職詐騙，請勿進行求職面試並與警方反詐騙專線165聯繫，同時向1111反映問題。</li>
# </ol>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <!--包邊內容 --> <div id="FOOTER" style="text-align: center">
# <span class="word_Gray11" style="font-size: 11px">以上求才資訊係由各該廠商提供，不代表本網站意見。</span><br/>
# </div>
# <div class="section">
# <h3>相關推薦</h3>
# <dl class="moreInfo"><input id="noNo" name="noNo" type="hidden" value="71696908"/><input id="dutyall" name="dutyall" type="hidden" value="140213"/><input id="workcity" name="workcity" type="hidden" value="100907"/><input id="eduty0" name="eduty0" type="hidden" value="140213"/><input id="eduty1" name="eduty1" type="hidden" value="140212"/><input id="eduty2" name="eduty2" type="hidden" value="140202"/><input id="nShowField" name="nShowField" type="hidden" value="0"/><input id="eDutyV" name="eDutyV" type="hidden" value="140213,140212,140202,0,0"/><input id="eRole" name="eRole" type="hidden" value="1"/> <dd id="otherjobs"></dd><dd id="similar"></dd><dd id="recommend"></dd><dd id="education"></dd>
# <script type="text/javascript">
# var vizLayer = {
# type: 'product_page',
# pid: 79812705,
# pname: 'Javascript 網頁工程師',
# lp : location.href,
# image: 'https://photos-4.dropbox.com/t/2/AABOyZA6Q4_aw5ZOHyQc1GYhGv1xxVlYH79C0piHtVzk9A/12/488048825/jpeg/1024x1024/2/_/0/5/100100.jpg/CLmR3OgBIAEgAiAEIAUgBygH/0ktvxstls9m1hwm/AAAfar1vBs2muOX7jGP6ucF-a/0?mode=1&size=320x320',
# newprice: '月薪 45,000元 至 60,000元',
# catid: 140213,
# catname: '卡貓科技有限公司',
# subcatname: '熟悉 Javacsript者。 <br />有用Javascript寫過遊戲者優先錄取 <br />熟Java者亦可',
# availability: 1,
# Logged: 0
# };
# </script> </dl>
# </div>
# </div>
# </div>
# <div style="clear: both;"></div>
# <div id="footer"></div>
# <!-- Facebook Conversion Code for 1111公司職缺頁 -->
# <script type="text/javascript">
#             var fb_param = {};
#             fb_param.pixel_id = '6010264740988';
#             fb_param.value = '0.00';
#             fb_param.currency = 'TWD';
#             (function () {
#                 var fpw = document.createElement('script');
#                 fpw.async = true;
#                 fpw.src = '//connect.facebook.net/en_US/fp.js';
#                 var ref = document.getElementsByTagName('script')[0];
#                 ref.parentNode.insertBefore(fpw, ref);
#             })();
#         </script>
# <noscript><img alt="" height="1" src="https://www.facebook.com/offsite_event.php?id=6010264740988&amp;value=0&amp;currency=TWD" style="display: none" width="1"/></noscript>
# <script src="/includesU/talentDetailItem.js" type="text/javascript"></script>
# <input id="showbn" name="showbn" type="hidden" value="0"/>
# <script src="/talents/MicroBlogging/share.js?v=201702131515" type="text/javascript"></script><script src="/includesU/fancyBox.2.1.5/source/jquery.fancybox.pack.js" type="text/javascript"></script><script src="/includesU/jqWindowsEngine/jquery.windows-engine.js" type="text/javascript"></script><script src="/includesU/jquery.scrollto.js" type="text/javascript"></script><script src="/includesU/jquery.alerts.js" type="text/javascript"></script><script src="/job-bank/job-description.js?v=201702131515" type="text/javascript"></script>
# <input name="showagentfromout" type="hidden" value=""/>
# <input name="showagent" type="hidden" value="home_20170507"/>
# <input id="HTTP_REFERER" name="HTTP_REFERER" type="hidden" value=""/>
# <input id="HTTP_USER_AGENT" name="HTTP_USER_AGENT" type="hidden" value="python-requests/2.13.0"/>
# <script type="text/javascript">
# <!--
# try{
#   (function() {
# 		var sp = document.createElement('script'); sp.type = 'text/javascript'; sp.async = true;
# 		sp.src = '/counter/sp_temp.asp?URL=/job-bank/job-description.asp-home_20170507&vCount=&web=Web103&xRow=';
#     var sn = document.getElementsByTagName('script')[0]; sn.parentNode.insertBefore(sp, sn);
#   })();
# }catch(e){}
# //-->
# </script>
# <script type="text/javascript">
# <!--
#     _url = location.href;
#     if ((location.hostname.indexOf("1111.com.tw") >= 0 || location.hostname.indexOf("jobforum.tw") >= 0) && location.hostname.indexOf("mt.1111.com.tw") == -1 && location.pathname.toLowerCase().indexOf("membermail2organmemo.asp") == -1) {
#         if (location.protocol == 'http:') {
#             location.href = _url.replace('http:', 'https:').replace('https://1111.com.tw', 'https://www.1111.com.tw').replace('www.ekuso.com.tw/11sp', 'www.1111.com.tw/11sp').replace('www.jobsalary.com.tw/11sp', 'www.1111.com.tw/11sp');
#         }
#     }
#     if (_url.indexOf('https://1111.com.tw') > -1) {
#         location.href = _url.replace('https://1111.com.tw', 'https://www.1111.com.tw');
#     }
#     if (_url.indexOf('mamama.com.tw') > -1) {
#         location.href = _url.replace('mamama.com.tw', '1111.com.tw');
#     }
# //-->
# </script>
# <script src="/adbanner/adImpression_jquery.js" type="text/javascript"></script>
# <script src="/adbanner/adImpression.js" type="text/javascript"></script>
# <script src="/adbanner/adkeyword.js" type="text/javascript"></script>
# <script type="text/javascript">
# try {
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   	(i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
# 		m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
# 	ga('create', 'UA-934279-1', 'auto');
# 	ga('send', 'pageview');
# }catch(e){
# }
# </script>
# <div style="display:none;">
# <!--==================== 【2016/12/30 上午 10:15:00】發發圖 Google ====================-->
# <script type="text/javascript">
# /* <![CDATA[ */
# var google_conversion_id = 878598800;
# var google_custom_params = window.google_tag_params;
# var google_remarketing_only = true;
# /* ]]> */
# </script>
# <script src="//www.googleadservices.com/pagead/conversion.js" type="text/javascript">
# </script>
# <noscript>
# <div style="display:inline;">
# <img alt="" height="1" src="//googleads.g.doubleclick.net/pagead/viewthroughconversion/878598800/?guid=ON&amp;script=0" style="border-style:none;" width="1"/>
# </div>
# </noscript>
# <!--==================== 【2016/3/31 下午 02:03:00】Facebook ====================-->
# <!-- Facebook Pixel Code -->
# <script>
# !function(f,b,e,v,n,t,s){if(f.fbq)return;n=f.fbq=function(){n.callMethod?
# n.callMethod.apply(n,arguments):n.queue.push(arguments)};if(!f._fbq)f._fbq=n;
# n.push=n;n.loaded=!0;n.version='2.0';n.queue=[];t=b.createElement(e);t.async=!0;
# t.src=v;s=b.getElementsByTagName(e)[0];s.parentNode.insertBefore(t,s)}(window,
# document,'script','https://connect.facebook.net/en_US/fbevents.js');
#
# fbq('init', '314405988707400');
# fbq('track', "PageView");</script>
# <noscript><img height="1" src="https://www.facebook.com/tr?id=314405988707400&amp;ev=PageView&amp;noscript=1" style="display:none" width="1"/></noscript>
# <!-- End Facebook Pixel Code -->
# <!--==================== 【2016/11/15 下午 04:48:00】Yahoo原生廣告 ====================-->
# <script type="application/javascript">(function(w,d,t,r,u){w[u]=w[u]||[];w[u].push({'projectId':'10000','properties':{'pixelId':'10016626'}});var s=d.createElement(t);s.src=r;s.async=true;s.onload=s.onreadystatechange=function(){var y,rs=this.readyState,c=w[u];if(rs&&rs!="complete"&&rs!="loaded"){return}try{y=YAHOO.ywa.I13N.fireBeacon;w[u]=[];w[u].push=function(p){y([p])};y(c)}catch(e){}};var scr=d.getElementsByTagName(t)[0],par=scr.parentNode;par.insertBefore(s,scr)})(window,document,"script","https://s.yimg.com/wi/ytc.js","dotq");</script>
# <!--==================== 【2015/10/12 下午 03:01:00】Bing Ads ====================-->
# <script>(function(w,d,t,r,u){var f,n,i;w[u]=w[u]||[],f=function(){var o={ti:"4014341"};o.q=w[u],w[u]=new UET(o),w[u].push("pageLoad")},n=d.createElement(t),n.src=r,n.async=1,n.onload=n.onreadystatechange=function(){var s=this.readyState;s&&s!=="loaded"&&s!=="complete"||(f(),n.onload=n.onreadystatechange=null)},i=d.getElementsByTagName(t)[0],i.parentNode.insertBefore(n,i)})(window,document,"script","//bat.bing.com/bat.js","uetq");</script><noscript><img height="0" src="//bat.bing.com/action/0?ti=4014341&amp;Ver=2" style="display:none; visibility: hidden;" width="0"/></noscript>
# <!--==================== 【2015/10/7 上午 09:54:00】Bing Ads UET ====================-->
# <script>(function(w,d,t,r,u){var f,n,i;w[u]=w[u]||[],f=function(){var o={ti:"4014341"};o.q=w[u],w[u]=new UET(o),w[u].push("pageLoad")},n=d.createElement(t),n.src=r,n.async=1,n.onload=n.onreadystatechange=function(){var s=this.readyState;s&&s!=="loaded"&&s!=="complete"||(f(),n.onload=n.onreadystatechange=null)},i=d.getElementsByTagName(t)[0],i.parentNode.insertBefore(n,i)})(window,document,"script","//bat.bing.com/bat.js","uetq");</script><noscript><img height="0" src="//bat.bing.com/action/0?ti=4014341&amp;Ver=2" style="display:none; visibility: hidden;" width="0"/></noscript>
# </div><!-- Start Alexa Certify Javascript -->
# <script type="text/javascript">
#     _atrk_opts = { atrk_acct: "lIjii1agq800gT", domain: "1111.com.tw", dynamic: true };
#     (function () { var as = document.createElement('script'); as.type = 'text/javascript'; as.async = true; as.src = "https://d31qbv1cthcecs.cloudfront.net/atrk.js"; var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(as, s); })();
# </script>
# <noscript><img alt="" height="1" src="https://d5nxst8fruw4z.cloudfront.net/atrk.gif?account=lIjii1agq800gT" style="display:none" width="1"/></noscript>
# <!-- End Alexa Certify Javascript --><input name="nowurl" type="hidden" value="/job-bank/job-description.asp"/>
# <script type="text/javascript">
# var product = {
#         identifier: '79812705',
#         category : [ '台中市','軟體工程','網站程式設計師' ],
#         fn: 'Javascript 網頁工程師',
#         description: '台中市西屯區 / 薪資： 月薪 45,000元 至 60,000元',
#         brand: '卡貓科技有限公司',
#         price: '1',
#         amount: '1',
#         currency: 'TWD',
#         url: 'http://www.1111.com.tw/job-bank/job-description.asp?eNo=79812705',
#         photo: 'https://photos-4.dropbox.com/t/2/AABOyZA6Q4_aw5ZOHyQc1GYhGv1xxVlYH79C0piHtVzk9A/12/488048825/jpeg/1024x1024/2/_/0/5/100100.jpg/CLmR3OgBIAEgAiAEIAUgBygH/0ktvxstls9m1hwm/AAAfar1vBs2muOX7jGP6ucF-a/0?mode=1&size=320x320',
#         valid: '0'
#     };
# </script>
# <script type="text/javascript">
# var customer = {segment: 2};
# (function(){
#     var s   = document.createElement('script');
#     var x   = document.getElementsByTagName('script')[0];
#     s.type  = 'text/javascript';
#     s.async = true;
#     s.src   = ('https:'==document.location.protocol?'https://':'http://')
#             + 'ap-sonar.sociomantic.com/js/2010-07-01/adpan/1111-tw';
#     x.parentNode.insertBefore( s, x );
# })();
# </script><input name="nowurl" type="hidden" value="/job-bank/job-description.asp"/>
# <script async="true" src="//static.criteo.net/js/ld/ld.js" type="text/javascript"></script>
# <script type="text/javascript">
# window.criteo_q = window.criteo_q || [];
# window.criteo_q.push(
#         { event: "setAccount", account: 24594 },
#         { event: "setHashedEmail", email: "" },
#         { event: "setSiteType", type: "d" },
#         { event: "viewItem", item: "E79812705", user_segment: "0" }
# );
# </script>
# <input name="WebPage" type="hidden" value="dynamic"/><script src="//www.1111.com.tw/includesU/toplink/topLinkNew.js" type="text/javascript"></script><link href="//www.1111.com.tw/includesU/topLink/topLink.css" rel="stylesheet" type="text/css"/>
# <div class="toplinkzone">
# <ul class="navigationLogo">
# <li><a ad_id="32811" href="https://www.1111.com.tw/" id="toplink_32811" onclick="setHref('32811')" style="font-weight: bold;" target="_blank">人力銀行<span class="blueTxt"> </span></a></li>
# </ul>
# <ul class="navigation1">
# <li><a ad_id="32819" href="https://central.1111.com.tw/" id="toplink_32819" onclick="setHref('32819')" target="_blank">中部工作<span class="blueTxt"> </span></a></li>
# </ul>
# <ul class="navigation1">
# <li><a ad_id="32820" href="https://south.1111.com.tw/" id="toplink_32820" onclick="setHref('32820')" target="_blank">南部工作<span class="blueTxt"> </span></a></li>
# </ul>
# <ul class="navigation1">
# <li><a ad_id="129684" href="http://trade.1111.com.tw/" id="toplink_129684" onclick="setHref('129684')" style="color:yellow" target="_blank">商搜網<span class="blueTxt"> </span></a></li>
# </ul>
# <ul class="navigation1">
# <li><a ad_id="129683" href="https://twhere.1111.com.tw/" id="toplink_129683" onclick="setHref('129683')" target="_blank">特惠王<span class="blueTxt"> </span></a></li>
# </ul>
# <ul class="navigation1">
# <li><a ad_id="229719" href="https://www.1111.com.tw/15sp/delicacy/" id="toplink_229719" onclick="setHref('229719')" target="_blank">台灣美食<span class="blueTxt"> </span></a></li>
# </ul>
# <ul class="navigation1">
# <li><a ad_id="229717" href="http://www.taiwanxing.com.tw/" id="toplink_229717" onclick="setHref('229717')" target="_blank">台灣行<span class="blueTxt"> </span></a></li>
# </ul>
# <ul class="navigation1">
# <li><a ad_id="214692" href="http://university.1111.com.tw/Default.aspx" id="toplink_214692" onclick="setHref('214692')" target="_blank">大學網<span class="blueTxt"> </span></a></li>
# </ul>
# <ul class="navigation1">
# <li><a ad_id="213787" href="https://love.1111.com.tw/" id="toplink_213787" onclick="setHref('213787')" style="color:#c57fe4;" target="_blank">婚戀<span class="blueTxt"> </span></a></li>
# </ul>
# <ul class="navigation1">
# <li><a ad_id="129674" href="http://www.1111edu.com.tw/" id="toplink_129674" onclick="setHref('129674')" target="_blank">進修<span class="blueTxt"> </span></a></li>
# </ul>
# <ul class="navigation1">
# <li><a ad_id="129675" href="http://www.1111boss.com.tw/" id="toplink_129675" onclick="setHref('129675')" target="_blank">創業<span class="blueTxt"> </span></a></li>
# </ul>
# <ul class="navigation1">
# <li><a ad_id="229718" href="https://www.11tv.com.tw/" id="toplink_229718" onclick="setHref('229718')" target="_blank">11TV<span class="blueTxt"> </span></a></li>
# </ul>
# <ul class="navigation1"></ul>
# <ul class="navigation1 moremore" id="moremoreid">
# <li class="list5"><a href="javascript:void(0);" id="showtoplinkmore" onclick="if(document.getElementById('showtopmenu').style.display == ''){document.getElementById('showtopmenu').style.display = 'none';}else{document.getElementById('showtopmenu').style.display = '';}">更多▼<span class="blueTxt"> </span></a>
# <dl id="showtopmenu" style="display: none; z-index: 1000; position: absolute; width: 120px">
# <dd><a ad_id="129676" href="http://www.jobwiki.com.tw/" id="toplink_129676" onclick="setHref('129676')" target="_blank">職務大辭典</a></dd>
# <dd class="bottmline"><a ad_id="129677" href="https://assessment.1111.com.tw/cstar/index.aspx" id="toplink_129677" onclick="setHref('129677')" target="_blank">九大職能星</a></dd>
# <dd><a ad_id="32814" href="https://www.1111.com.tw/zone/school_fresh/" id="toplink_32814" onclick="setHref('32814')" target="_blank">社會新鮮人</a></dd>
# <dd><a ad_id="209896" href="https://www.1111.com.tw/11sp/hot/index.asp" id="toplink_209896" onclick="setHref('209896')" target="_blank">工作自由配</a></dd>
# <dd class="bottmline"><a ad_id="77821" href="https://www.1111.com.tw/zone/service/" id="toplink_77821" onclick="setHref('77821')" target="_blank">服務業</a></dd>
# <dd class="last"><a href="//www.1111.com.tw/webmap.asp" target="_blank">全部&gt;&gt;</a></dd>
# </dl>
# </li>
# </ul>
# <ul class="navigation3">
# <li class="AD">
# <div class="addiv" id="addivid"></div>
# </li>
# </ul>
# <ul class="navigation4"><li><a ad_id="188642" href="//www.1111.com.tw/talents/memberlogin.asp?ref=http%3A%2F%2Fwww%2E1111%2Ecom%2Etw%2Fjob%2Dbank%2Fjob%2Ddescription%2Easp?eNo%3D79812705" onclick="setHref('188642');" target="_top">會員登入</a></li><li class="otherline newMember">│</li><li class="newMember"><a ad_id="188643" href="//www.1111.com.tw/talents/membercenter/resumeNew_1.asp?agent=home_20170507&amp;ref=http://www.1111.com.tw/job-bank/job-description.asp" onclick="setHref('188643');" target="_blank">加入會員</a></li><li class="job" style="margin-right: 20px;"><a ad_id="188644" href="//www.1111.com.tw/help/faq.asp" onclick="setHref('188644');" onmouseout="$('#toplinkfaq').hide();" onmouseover="$('#toplinkfaq').show();" target="_blank">    </a>
# <div id="toplinkfaq" style="position: absolute; display: none;">
# <div style="position: relative; top: -10px; left: -15px;">
# <img src="//www.1111.com.tw/includesU/toplink/images/icon_hover.png"/></div>
# </div>
# </li>
# </ul>
# </div>
# <script language="javascript" type="text/javascript">getTopLink('32811,32819,32820,129684,129683,229719,229717,214692,213787,129674,129675,229718,129676,129677,32814,209896,77821');showspace();</script>
# </body>
# </html>
